# %%
import json
import pandas as pd
data1 = json.load(open("Wetter.json"))
data2 = json.load(open("Drache.json"))

# %%
data1.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
data2.keys()
# Out:
# dict_keys(['types', 'properties', 'items'])

# %%
df_search1 = pd.DataFrame(data1["items"])
df_search2 = pd.DataFrame(data2["items"])

# %%
df_search1
# Out:
#             type                                                 id  \
# 0       Bookmark  https://www.bibsonomy.org/url/f58cf38a7e54a86f...
# 1       Bookmark  https://www.bibsonomy.org/url/daa3a99cee44a0ce...
# 2       Bookmark  https://www.bibsonomy.org/url/f2e15018f319c3d4...
# 3       Bookmark  https://www.bibsonomy.org/url/48c760ac3937a038...
# 4       Bookmark  https://www.bibsonomy.org/url/87ef59608b52d6a2...
# ..           ...                                                ...
# 195  Publication  https://www.bibsonomy.org/bibtex/2772585f0ebb7...
# 196  Publication  https://www.bibsonomy.org/bibtex/2a80388f655b4...
# 197  Publication  https://www.bibsonomy.org/bibtex/2211504a86fce...
# 198  Publication  https://www.bibsonomy.org/bibtex/2f8bd7842e045...
# 199  Publication  https://www.bibsonomy.org/bibtex/2678cad585267...
#
#                                                   tags  \
# 0                                  [wetter, frankfurt]
# ...

# %%
df_search1["Suchbegriff"] = "Wetter"
df_search1
# Out:
#             type                                                 id  \
# 0       Bookmark  https://www.bibsonomy.org/url/f58cf38a7e54a86f...
# 1       Bookmark  https://www.bibsonomy.org/url/daa3a99cee44a0ce...
# 2       Bookmark  https://www.bibsonomy.org/url/f2e15018f319c3d4...
# 3       Bookmark  https://www.bibsonomy.org/url/48c760ac3937a038...
# 4       Bookmark  https://www.bibsonomy.org/url/87ef59608b52d6a2...
# ..           ...                                                ...
# 195  Publication  https://www.bibsonomy.org/bibtex/2772585f0ebb7...
# 196  Publication  https://www.bibsonomy.org/bibtex/2a80388f655b4...
# 197  Publication  https://www.bibsonomy.org/bibtex/2211504a86fce...
# 198  Publication  https://www.bibsonomy.org/bibtex/2f8bd7842e045...
# 199  Publication  https://www.bibsonomy.org/bibtex/2678cad585267...
#
#                                                   tags  \
# 0                                  [wetter, frankfurt]
# ...

# %%
df_search2
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/0a53f83ea5943b77...
# 1        Bookmark  https://www.bibsonomy.org/url/eeef96431ecdf761...
# 2        Bookmark  https://www.bibsonomy.org/url/c33de74f80ea8647...
# 3        Bookmark  https://www.bibsonomy.org/url/6126f73e79aed27c...
# 4        Bookmark  https://www.bibsonomy.org/url/70d3f5792f014106...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2e1741a622ce0...
# 1996  Publication  https://www.bibsonomy.org/bibtex/2579ff7c1af43...
# 1997  Publication  https://www.bibsonomy.org/bibtex/2be5e967c5d95...
# 1998  Publication  https://www.bibsonomy.org/bibtex/270cba074ed66...
# 1999  Publication  https://www.bibsonomy.org/bibtex/22ecd12581094...
#
#                                                    tags  \
# 0                                            [imported]
# ...

# %%
df_search2["Suchbegriff"] = "Drache"
df_search2
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/0a53f83ea5943b77...
# 1        Bookmark  https://www.bibsonomy.org/url/eeef96431ecdf761...
# 2        Bookmark  https://www.bibsonomy.org/url/c33de74f80ea8647...
# 3        Bookmark  https://www.bibsonomy.org/url/6126f73e79aed27c...
# 4        Bookmark  https://www.bibsonomy.org/url/70d3f5792f014106...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2e1741a622ce0...
# 1996  Publication  https://www.bibsonomy.org/bibtex/2579ff7c1af43...
# 1997  Publication  https://www.bibsonomy.org/bibtex/2be5e967c5d95...
# 1998  Publication  https://www.bibsonomy.org/bibtex/270cba074ed66...
# 1999  Publication  https://www.bibsonomy.org/bibtex/22ecd12581094...
#
#                                                    tags  \
# 0                                            [imported]
# ...

# %%
df_both = pd.concat([df_search1, df_search2])

# %%
df_both
# Out:
#              type                                                 id  \
# 0        Bookmark  https://www.bibsonomy.org/url/f58cf38a7e54a86f...
# 1        Bookmark  https://www.bibsonomy.org/url/daa3a99cee44a0ce...
# 2        Bookmark  https://www.bibsonomy.org/url/f2e15018f319c3d4...
# 3        Bookmark  https://www.bibsonomy.org/url/48c760ac3937a038...
# 4        Bookmark  https://www.bibsonomy.org/url/87ef59608b52d6a2...
# ...           ...                                                ...
# 1995  Publication  https://www.bibsonomy.org/bibtex/2e1741a622ce0...
# 1996  Publication  https://www.bibsonomy.org/bibtex/2579ff7c1af43...
# 1997  Publication  https://www.bibsonomy.org/bibtex/2be5e967c5d95...
# 1998  Publication  https://www.bibsonomy.org/bibtex/270cba074ed66...
# 1999  Publication  https://www.bibsonomy.org/bibtex/22ecd12581094...
#
#                                                    tags  \
# 0                                   [wetter, frankfurt]
# ...
