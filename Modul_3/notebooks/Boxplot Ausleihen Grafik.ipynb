# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

import pandas as pd

df = pd.read_csv("data/Library_Usage.csv")
df = df[df['Total Checkouts'] < 816]
plt.figure(figsize=(16, 6))
plt = sns.boxplot(y='Total Checkouts', x='Year Patron Registered', data=df, fliersize=0.5, whis=1.5)
plt.get_figure().savefig("boxplots.png")
# Out:
# /tmp/ipykernel_95895/1018102084.py:7: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/Library_Usage.csv")
