# %%
# import the libraries and give them some shorter names
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# setup the seaborn library, mit diesem Befehl sieht alles schöner aus. Test: erst unten ausführen, anschauen. 
#Dann diesen Befehl hier und erneut unten ausführen
sns.set_theme()

# %%
# create the same plot as in the previous example
x = range(1, 10)
plt.plot(x, x)
