# %%
import pandas as pd
import csv

# %%
# Read the CSV file
Library_data = pd.read_csv("data/Library_Usage.csv")
# Out:
# /tmp/ipykernel_60281/825488449.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   Library_data = pd.read_csv("data/Library_Usage.csv")

# %%
df_library = pd.DataFrame(Library_data)

# %%
df_library
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                      Senior                5               0
# 1                       Adult                0               0
# 2                       Adult                0               0
# 3                     Welcome                1               1
# 4                      Senior                0               0
# ...                       ...              ...             ...
# 450354    Digital Access Card                0               0
# 450355    Digital Access Card                0               0
# 450356    Digital Access Card                0               0
# 450357    Digital Access Card                0               0
# 450358    Digital Access Card                0               0
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 0       75 years and over                    Main                      Nov
# ...

# %%
df_library["Circulation Active Year"].unique()
# Out:
# array(['2022', '2023', '2024', '2021', 'Null', '2012', '2020', '2018',
#        '2019', '2013', '2015', '2017', '2016', '2011', '2009', '2014',
#        '2010', '2006', '2007', '2008', '2004', '2005'], dtype=object)

# %%
# 1. Wie viele Merkmale besitzt der Datensatz? Die Merkmale entsprechen den Spalten
len(df_library.columns)
# Out:
# 11

# %%
# 2.Wie groß ist die Stichprobengröße des Datensatzes?
len(df_library)
# Out:
# 450359

# %%
df_library['Year Patron Registered'].value_counts(normalize=True)
# Out:
# Year Patron Registered
# 2023    0.132654
# 2022    0.115015
# 2003    0.088927
# 2021    0.072678
# 2019    0.072502
# 2020    0.065870
# 2017    0.064515
# 2018    0.062939
# 2016    0.048117
# 2015    0.043767
# 2014    0.033917
# 2013    0.028750
# 2012    0.027600
# 2011    0.026841
# 2009    0.024580
# 2010    0.024363
# 2008    0.021705
# 2007    0.014033
# 2006    0.011302
# 2005    0.010263
# 2004    0.009661
# Name: proportion, dtype: float64

# %%
# 8. Enthält der Datensatz fehlende Werte? Ja, z.B. 'Circulation Active Year'

# %%
df_library[df_library['Circulation Active Year'].isna()]
# Out:
# Empty DataFrame
# Columns: [Patron Type Definition, Total Checkouts, Total Renewals, Age Range, Home Library Definition, Circulation Active Month, Circulation Active Year, Notice Preference Definition, Provided Email Address, Year Patron Registered, Within San Francisco County]
# Index: []

# %%
row_filter = (df_library['Age Range'] == '20 to 24 years') 
df_library.loc[row_filter]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 3                     Welcome                1               1
# 6                       Adult                0               0
# 308                     Adult                0               0
# 323                     Adult               62               1
# 338                     Adult                0               0
# ...                       ...              ...             ...
# 450186                  Adult                0               0
# 450255                   Teen                1               0
# 450284    Digital Access Card                0               0
# 450304    Digital Access Card                0               0
# 450330    Digital Access Card                0               0
#
#              Age Range Home Library Definition Circulation Active Month  \
# 3       20 to 24 years                Richmond                      Aug
# ...

# %%
df_library['Patron Type Definition'].value_counts()
# Out:
# Patron Type Definition
# Adult                  284671
# Juvenile                57486
# Senior                  49025
# Teen                    41042
# Welcome                  9412
# Digital Access Card      4558
# Teacher Card             3415
# Retired Staff             211
# Visitor                   184
# At User Adult             126
# Library By Mail           116
# At User Senior             73
# At User Welcome            14
# At User Teen                8
# Business                    7
# At User Juvenile            6
# Bibliocommons               5
# Name: count, dtype: int64

# %%
df_library['Age Range'].value_counts()
# Out:
# Age Range
# 25 to 34 years       95278
# 35 to 44 years       85669
# 10 to 19 years       67758
# 45 to 54 years       49820
# 0 to 9 years         33180
# 65 to 74 years       32455
# 20 to 24 years       27145
# 75 years and over    20721
# 55 to 59 years       19735
# 60 to 64 years       18088
# Null                   510
# Name: count, dtype: int64

# %%
#Kreuztabellierung erstellen mit crosstab
#Infos zu margins und normalize hier: https://docs.kanaries.net/de/topics/Pandas/pandas-crosstab
pd.crosstab(
    df_library['Patron Type Definition'],
    df_library['Notice Preference Definition'],
    margins=True,
    normalize=1
)
# Out:
# Notice Preference Definition     Email      Null     Phone     Print       All
# Patron Type Definition
# Adult                         0.658182  0.272700  0.370230  0.444515  0.632098
# At User Adult                 0.000259  0.000000  0.000410  0.001118  0.000280
# At User Juvenile              0.000012  0.000302  0.000000  0.000000  0.000013
# At User Senior                0.000127  0.000302  0.000536  0.000479  0.000162
# At User Teen                  0.000020  0.000000  0.000000  0.000000  0.000018
# At User Welcome               0.000032  0.000000  0.000032  0.000000  0.000031
# Bibliocommons                 0.000002  0.000000  0.000095  0.000160  0.000011
# Business                      0.000017  0.000000  0.000000  0.000000  0.000016
# Digital Access Card           0.006874  0.306787  0.009713  0.067220  0.010121
# Juvenile                      0.121162  0.247964  0.183664  0.203736  0.127645
# Library By Mail               0.000242  0.000000  0.000410  0.000639  0.000258
# ...

# %%
pd.crosstab(
    df_library['Age Range'],
    df_library['Notice Preference Definition'],
    margins=True,
    normalize=1
)
# Out:
# Notice Preference Definition     Email      Null     Phone     Print       All
# Age Range
# 0 to 9 years                  0.073520  0.149321  0.049827  0.164458  0.073675
# 10 to 19 years                0.137177  0.157164  0.330937  0.100271  0.150453
# 20 to 24 years                0.059999  0.056712  0.067802  0.041993  0.060274
# 25 to 34 years                0.222186  0.215083  0.084358  0.159668  0.211560
# 35 to 44 years                0.199476  0.195777  0.077326  0.154559  0.190224
# 45 to 54 years                0.114398  0.092006  0.066919  0.095162  0.110623
# 55 to 59 years                0.044212  0.032881  0.039767  0.044547  0.043821
# 60 to 64 years                0.039335  0.036501  0.049732  0.047741  0.040164
# 65 to 74 years                0.068416  0.042534  0.116682  0.100112  0.072065
# 75 years and over             0.040181  0.019910  0.115926  0.086540  0.046010
# Null                          0.001098  0.002112  0.000725  0.004950  0.001132

# %%
pd.crosstab(
    df_library['Patron Type Definition'],
    df_library['Age Range'],
    margins=True,
    normalize=1
)
# Out:
# Age Range               0 to 9 years  10 to 19 years  20 to 24 years  \
# Patron Type Definition
# Adult                       0.002230        0.030048        0.943968
# At User Adult               0.000000        0.000015        0.000258
# At User Juvenile            0.000090        0.000044        0.000000
# At User Senior              0.000000        0.000000        0.000000
# At User Teen                0.000000        0.000118        0.000000
# At User Welcome             0.000000        0.000044        0.000037
# Bibliocommons               0.000000        0.000000        0.000000
# Business                    0.000000        0.000000        0.000000
# Digital Access Card         0.000181        0.001638        0.010978
# Juvenile                    0.994967        0.360725        0.000147
# Library By Mail             0.000000        0.000000        0.000074
# Retired Staff               0.000000        0.000000        0.000000
# ...
