# %%
import pandas as pd
import csv

# %%
# Read the CSV file
Library_data = pd.read_csv("data/Library_Usage.csv")
# Out:
# /tmp/ipykernel_77315/825488449.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   Library_data = pd.read_csv("data/Library_Usage.csv")

# %%
df_library = pd.DataFrame(Library_data)

# %%
df_library.columns
# Out:
# Index(['Patron Type Definition', 'Total Checkouts', 'Total Renewals',
#        'Age Range', 'Home Library Definition', 'Circulation Active Month',
#        'Circulation Active Year', 'Notice Preference Definition',
#        'Provided Email Address', 'Year Patron Registered',
#        'Within San Francisco County'],
#       dtype='object')

# %%
df_library
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                      Senior                5               0
# 1                       Adult                0               0
# 2                       Adult                0               0
# 3                     Welcome                1               1
# 4                      Senior                0               0
# ...                       ...              ...             ...
# 450354    Digital Access Card                0               0
# 450355    Digital Access Card                0               0
# 450356    Digital Access Card                0               0
# 450357    Digital Access Card                0               0
# 450358    Digital Access Card                0               0
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 0       75 years and over                    Main                      Nov
# ...

# %%
#Spalte die eigentlich Text ist, in Zahlen umwandeln und dann direkt die Spalte so überschreiben
df_library['Circulation Active Year'] = pd.to_numeric(
  df_library['Circulation Active Year'], errors='coerce'
)

# %%
df_library['Circulation Active Year']
# Out:
# 0         2022.0
# 1         2023.0
# 2         2024.0
# 3         2022.0
# 4         2024.0
#            ...
# 450354       NaN
# 450355    2022.0
# 450356    2022.0
# 450357    2022.0
# 450358    2023.0
# Name: Circulation Active Year, Length: 450359, dtype: float64

# %%
df_library.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450359 entries, 0 to 450358
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Patron Type Definition        450359 non-null  object
#  1   Total Checkouts               450359 non-null  int64
#  2   Total Renewals                450359 non-null  int64
#  3   Age Range                     450359 non-null  object
#  4   Home Library Definition       450359 non-null  object
#  5   Circulation Active Month      410042 non-null  datetime64[ns]
#  6   Circulation Active Year       410042 non-null  float64
#  7   Notice Preference Definition  450359 non-null  object
#  8   Provided Email Address        450359 non-null  bool
#  9   Year Patron Registered        450359 non-null  int64
#  10  Within San Francisco County   450359 non-null  object
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(3), object(5)
# ...

# %%
#Spalte ins Datumsformat umwandeln und ebenfalls überschreiben
df_library['Circulation Active Month'] = pd.to_datetime(
    df_library['Circulation Active Month'],
    errors='coerce',
    format="%b"
)

# %%
df_library['Circulation Active Month']
# Out:
# 0        1900-11-01
# 1        1900-07-01
# 2        1900-03-01
# 3        1900-08-01
# 4        1900-03-01
#             ...
# 450354          NaT
# 450355   1900-08-01
# 450356   1900-08-01
# 450357   1900-04-01
# 450358   1900-04-01
# Name: Circulation Active Month, Length: 450359, dtype: datetime64[ns]

# %%
#Extraktion des Monats als Zahl aus der Spalte
df_library['Circulation Active Month']= df_library['Circulation Active Month'].dt.month
df_library['Circulation Active Month']
# Out:
# 0         11.0
# 1          7.0
# 2          3.0
# 3          8.0
# 4          3.0
#           ...
# 450354     NaN
# 450355     8.0
# 450356     8.0
# 450357     4.0
# 450358     4.0
# Name: Circulation Active Month, Length: 450359, dtype: float64

# %%
#aktive Mitgliedschaft in Monaten ausrechnen
df_library['Membership Duration'] = (df_library['Circulation Active Year'] - df_library['Year Patron Registered'])*12 + df_library['Circulation Active Month']

# %%
df_library
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                      Senior                5               0
# 1                       Adult                0               0
# 2                       Adult                0               0
# 3                     Welcome                1               1
# 4                      Senior                0               0
# ...                       ...              ...             ...
# 450354    Digital Access Card                0               0
# 450355    Digital Access Card                0               0
# 450356    Digital Access Card                0               0
# 450357    Digital Access Card                0               0
# 450358    Digital Access Card                0               0
#
#                 Age Range Home Library Definition  Circulation Active Month  \
# 0       75 years and over                    Main                      11.0
# ...

# %%
df_library['Membership Duration'] = df_library['Membership Duration'].fillna(0)
df_library['Membership Duration']
# Out:
# 0         95.0
# 1         55.0
# 2         27.0
# 3          8.0
# 4         15.0
#           ...
# 450354     0.0
# 450355     8.0
# 450356     8.0
# 450357     4.0
# 450358     4.0
# Name: Membership Duration, Length: 450359, dtype: float64

# %%
df_library.head()
# Out:
#   Patron Type Definition  Total Checkouts  Total Renewals          Age Range  \
# 0                 Senior                5               0  75 years and over
# 1                  Adult                0               0     45 to 54 years
# 2                  Adult                0               0     55 to 59 years
# 3                Welcome                1               1     20 to 24 years
# 4                 Senior                0               0     65 to 74 years
#
#   Home Library Definition  Circulation Active Month  Circulation Active Year  \
# 0                    Main                      11.0                   2022.0
# 1                    Main                       7.0                   2023.0
# 2        Western Addition                       3.0                   2024.0
# 3                Richmond                       8.0                   2022.0
# 4                  Sunset                       3.0                   2024.0
#
# ...
