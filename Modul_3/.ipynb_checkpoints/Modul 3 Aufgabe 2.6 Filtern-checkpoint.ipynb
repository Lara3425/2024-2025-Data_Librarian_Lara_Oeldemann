# %%
import pandas as pd
df = pd.read_csv("data/Library_Usage.csv",low_memory=False)
df.loc[df['Total Checkouts'] > 10000]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 12694                  Senior            12233            5416
# 12925                  Senior            10428            1079
# 54102                  Senior            17663              56
# 54414                  Senior            12675            1422
# 59475                  Senior            11252            2628
# ...                       ...              ...             ...
# 293994                  Adult            39743             659
# 294100                  Adult            10454            8663
# 306622                  Adult            10065            3897
# 312053                  Adult            14825            3915
# 328352                  Adult            12122             122
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 12694   75 years and over                  Merced                      Mar
# 12925   75 years and over                  Ortega                      Mar
# 54102      65 to 74 years                  Marina                      Mar
# 54414      65 to 74 years               Chinatown                      Mar
# 59475      65 to 74 years                    Main                      Mar
# ...                   ...                     ...                      ...
# 293994     60 to 64 years                  Ortega                      Mar
# 294100     35 to 44 years                  Ortega                      Mar
# 306622     60 to 64 years      Golden Gate Valley                      Mar
# 312053     25 to 34 years                    Park                      Mar
# 328352     55 to 59 years                 Bayview                      Mar
#
#        Circulation Active Year Notice Preference Definition  \
# 12694                     2024                        Email
# 12925                     2024                        Email
# 54102                     2024                        Email
# 54414                     2024                        Email
# 59475                     2024                        Phone
# ...                        ...                          ...
# 293994                    2024                        Email
# 294100                    2024                        Email
# 306622                    2024                        Email
# 312053                    2024                        Email
# 328352                    2024                        Email
#
#         Provided Email Address  Year Patron Registered  \
# 12694                     True                    2003
# 12925                     True                    2003
# 54102                     True                    2008
# 54414                     True                    2003
# 59475                    False                    2013
# ...                        ...                     ...
# 293994                    True                    2003
# 294100                    True                    2003
# 306622                    True                    2003
# 312053                    True                    2003
# 328352                    True                    2003
#
#        Within San Francisco County
# 12694                        False
# 12925                        False
# 54102                        False
# 54414                        False
# 59475                         True
# ...                            ...
# 293994                        True
# 294100                        True
# 306622                        True
# 312053                        True
# 328352                        True
#
# [89 rows x 11 columns]

# %%
row_filter = df['Total Checkouts'] > 10000
df.loc[row_filter]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 12694                  Senior            12233            5416
# 12925                  Senior            10428            1079
# 54102                  Senior            17663              56
# 54414                  Senior            12675            1422
# 59475                  Senior            11252            2628
# ...                       ...              ...             ...
# 293994                  Adult            39743             659
# 294100                  Adult            10454            8663
# 306622                  Adult            10065            3897
# 312053                  Adult            14825            3915
# 328352                  Adult            12122             122
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 12694   75 years and over                  Merced                      Mar
# 12925   75 years and over                  Ortega                      Mar
# 54102      65 to 74 years                  Marina                      Mar
# 54414      65 to 74 years               Chinatown                      Mar
# 59475      65 to 74 years                    Main                      Mar
# ...                   ...                     ...                      ...
# 293994     60 to 64 years                  Ortega                      Mar
# 294100     35 to 44 years                  Ortega                      Mar
# 306622     60 to 64 years      Golden Gate Valley                      Mar
# 312053     25 to 34 years                    Park                      Mar
# 328352     55 to 59 years                 Bayview                      Mar
#
#        Circulation Active Year Notice Preference Definition  \
# 12694                     2024                        Email
# 12925                     2024                        Email
# 54102                     2024                        Email
# 54414                     2024                        Email
# 59475                     2024                        Phone
# ...                        ...                          ...
# 293994                    2024                        Email
# 294100                    2024                        Email
# 306622                    2024                        Email
# 312053                    2024                        Email
# 328352                    2024                        Email
#
#         Provided Email Address  Year Patron Registered  \
# 12694                     True                    2003
# 12925                     True                    2003
# 54102                     True                    2008
# 54414                     True                    2003
# 59475                    False                    2013
# ...                        ...                     ...
# 293994                    True                    2003
# 294100                    True                    2003
# 306622                    True                    2003
# 312053                    True                    2003
# 328352                    True                    2003
#
#        Within San Francisco County
# 12694                        False
# 12925                        False
# 54102                        False
# 54414                        False
# 59475                         True
# ...                            ...
# 293994                        True
# 294100                        True
# 306622                        True
# 312053                        True
# 328352                        True
#
# [89 rows x 11 columns]

# %%
#filtern nach Senioren die per Mail benachrichtigt werden wollen
row_filter = (df['Patron Type Definition'] == 'Senior') & (df['Notice Preference Definition'] == 'Email')
df.loc[row_filter]
# Out:
#        Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                      Senior                5               0
# 5                      Senior                0               0
# 27                     Senior                0               0
# 28                     Senior                0               0
# 29                     Senior                0               0
# ...                       ...              ...             ...
# 450101                 Senior                0               0
# 450102                 Senior                0               0
# 450142                 Senior                0               0
# 450143                 Senior                0               0
# 450144                 Senior                1               0
#
#                 Age Range Home Library Definition Circulation Active Month  \
# 0       75 years and over                    Main                      Nov
# 5       75 years and over                    Main                      Apr
# 27      75 years and over                    Main                      Oct
# 28         65 to 74 years                    Main                      Mar
# 29         65 to 74 years                    Main                      Aug
# ...                   ...                     ...                      ...
# 450101  75 years and over                    Main                      Mar
# 450102     65 to 74 years              Noe Valley                      Mar
# 450142     65 to 74 years                    Main                      Nov
# 450143     65 to 74 years                    Main                      Mar
# 450144  75 years and over                    Main                      Jan
#
#        Circulation Active Year Notice Preference Definition  \
# 0                         2022                        Email
# 5                         2021                        Email
# 27                        2023                        Email
# 28                        2024                        Email
# 29                        2023                        Email
# ...                        ...                          ...
# 450101                    2024                        Email
# 450102                    2024                        Email
# 450142                    2022                        Email
# 450143                    2024                        Email
# 450144                    2024                        Email
#
#         Provided Email Address  Year Patron Registered  \
# 0                         True                    2015
# 5                         True                    2009
# 27                        True                    2016
# 28                        True                    2016
# 29                        True                    2020
# ...                        ...                     ...
# 450101                    True                    2013
# 450102                    True                    2019
# 450142                    True                    2021
# 450143                    True                    2019
# 450144                    True                    2015
#
#        Within San Francisco County
# 0                            False
# 5                            False
# 27                           False
# 28                           False
# 29                           False
# ...                            ...
# 450101                       False
# 450102                       False
# 450142                        Null
# 450143                        Null
# 450144                        Null
#
# [40940 rows x 11 columns]

# %%
filter1 = (df['Total Checkouts'] >= 20) & (df['Total Checkouts'] <= 80)
filter2 =  df['Total Checkouts'].between(20, 80)
all(filter1 == filter2)
# Out:
# True

# %%
#Kinder unter 10 Jahren zählen
Kids = (df['Age Range'] == '0 to 9 years').sum()

# %%
Kids
# Out:
# 33180

# %%
#oder Alternative um Kinder unter 10 zu zählen:
print(len(df[df['Age Range'] == '0 to 9 years']))
# Out:
# 33180

# %%
Checkouts = df['Total Checkouts'] >= 20000

# %%
Checkouts.sum()
# Out:
# 7

# %%
#oder:
(df['Total Checkouts'] > 20000).sum()
# Out:
# 7

# %%
#Personen, die aus Richmond stammen
(df['Home Library Definition'] == 'Richmond').sum()
# Out:
# 21433

# %%
# Wie viele Prozent der Beobachtungen haben eine Membership Duration von Null Monaten?

# Hierfür wird die in Aufgabe 2.5 neu definierte Variable 'Membership Duration' benötigt. 
# Entweder rechnest Du mit der gleichen Datei wie aus Aufgabe 2.5 weiter, oder führst die dortigen Schritte
# noch einmal durch

### erneute Berechnung von 'Membership Duration' ###
df['Circulation Active Year'] = pd.to_numeric(
    df['Circulation Active Year'], errors='coerce'
)
#
df['Circulation Active Month'] = pd.to_datetime(
   df['Circulation Active Month'],
    errors='coerce',
    format="%b"
)
#
df['Circulation Active Month'] = df['Circulation Active Month'].dt.month

df['Membership Duration'] = (
   df['Circulation Active Year'] - df['Year Patron Registered']
)*12 + df['Circulation Active Month']
df['Membership Duration'] = df['Membership Duration'].fillna(0)
####                                             ###

print(len(df[df['Membership Duration'] == 0])/len(df))

# alternative
(df['Membership Duration'] == 0).mean()
# Out:
# 0.08952191473913033
# 0.08952191473913033
